# %% [markdown]
# #📌 Extracão

# %%
import pandas as pd

dados_clientes_telecom = pd.read_json('/content/TelecomX_Data.json')
dados_clientes_telecom
# Out:
#       customerID Churn                                           customer  \
# 0     0002-ORFBO    No  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 1     0003-MKNFE    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 2     0004-TLHLJ   Yes  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 3     0011-IGKFF   Yes  {'gender': 'Male', 'SeniorCitizen': 1, 'Partne...
# 4     0013-EXCHZ   Yes  {'gender': 'Female', 'SeniorCitizen': 1, 'Part...
# ...          ...   ...                                                ...
# 7262  9987-LUTYD    No  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 7263  9992-RRAMN   Yes  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 7264  9992-UJOEL    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 7265  9993-LHIEB    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 7266  9995-HOTOH    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
#
#                                                   phone  \
# ...

# %% [markdown]
# #🔧 Transformação

# %%
df_completo
# Out:
#       customerID Churn  gender  SeniorCitizen Partner Dependents  tenure  \
# 0     0002-ORFBO    No  Female              0     Yes        Yes       9
# 1     0003-MKNFE    No    Male              0      No         No       9
# 2     0004-TLHLJ   Yes    Male              0      No         No       4
# 3     0011-IGKFF   Yes    Male              1     Yes         No      13
# 4     0013-EXCHZ   Yes  Female              1     Yes         No       3
# ...          ...   ...     ...            ...     ...        ...     ...
# 7262  9987-LUTYD    No  Female              0      No         No      13
# 7263  9992-RRAMN   Yes    Male              0     Yes         No      22
# 7264  9992-UJOEL    No    Male              0      No         No       2
# 7265  9993-LHIEB    No    Male              0     Yes        Yes      67
# 7266  9995-HOTOH    No    Male              0     Yes        Yes      63
#
#      PhoneService     MultipleLines InternetService  ... OnlineBackup  \
# ...

# %%
clientes = pd.json_normalize(dados_clientes_telecom['customer'])
telefone = pd.json_normalize(dados_clientes_telecom['phone'])
internet = pd.json_normalize(dados_clientes_telecom['internet'])
conta= pd.json_normalize(dados_clientes_telecom['account'])

df_completo = pd.concat([
    dados_clientes_telecom[['customerID', 'Churn']],  # IDs e target
    clientes,
    telefone,
    internet,
    conta
], axis=1)

df_completo.head()
print(df_completo.info())
print(df_completo.describe(include = 'all'))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7267 entries, 0 to 7266
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7267 non-null   object
#  1   Churn             7267 non-null   object
#  2   gender            7267 non-null   object
#  3   SeniorCitizen     7267 non-null   int64
#  4   Partner           7267 non-null   object
#  5   Dependents        7267 non-null   object
#  6   tenure            7267 non-null   int64
#  7   PhoneService      7267 non-null   object
#  8   MultipleLines     7267 non-null   object
#  9   InternetService   7267 non-null   object
#  10  OnlineSecurity    7267 non-null   object
#  11  OnlineBackup      7267 non-null   object
#  12  DeviceProtection  7267 non-null   object
#  13  TechSupport       7267 non-null   object
#  14  StreamingTV       7267 non-null   object
#  15  StreamingMovies   7267 non-null   object
# ...

# %% [markdown]
# #📊 Carga e análise

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Dados para compor o grafico
data = {
    "Churn_No": {0: 76.393832, 1: 58.318739},
    "Churn_Yes": {0: 23.606168, 1: 41.681261},
}


df = pd.DataFrame(data)
df.index = ["Não Idoso (0)", "Idoso (1)"]


ax = df.plot(kind="bar", stacked=False, figsize=(8, 5))
plt.title("Taxa de Churn por SeniorCitizen")
plt.xlabel("Cliente Idoso")
plt.ylabel("Proporção (%)")
plt.xticks(rotation=0)
plt.legend(["Churn = Não", "Churn = Sim"])
for container in ax.containers:
    ax.bar_label(container, fmt="%.1f", label_type="edge", padding=2)
plt.show()

# %%
import numpy as np

df_completo['Churn'] = df_completo['Churn'].replace('', np.nan)
df_completo = df_completo.dropna(subset=['Churn'])
df_completo['Churn'].unique()  #tirando Nan do array
# Out:
# array(['No', 'Yes'], dtype=object)

# %%
pd.crosstab(df_completo['SeniorCitizen'], df_completo['Churn'], normalize='index') * 100
# Out:
# Churn                 No        Yes
# SeniorCitizen
# 0              76.393832  23.606168
# 1              58.318739  41.681261

# %%
df_completo['Churn'].value_counts(normalize=True) * 100
# Out:
# Churn
# No     73.463013
# Yes    26.536987
# Name: proportion, dtype: float64

# %%
df_completo['Churn'] = df_completo['Churn'].replace('', np.nan)
df_completo.groupby('Churn')['Charges.Monthly'].describe()
# Out:
# /tmp/ipython-input-1418165741.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_completo['Churn'] = df_completo['Churn'].replace('', np.nan)
#         count       mean        std    min    25%     50%   75%     max
# Churn
# No     5174.0  61.265124  31.092648  18.25  25.10  64.425  88.4  118.75
# Yes    1869.0  74.441332  24.666053  18.85  56.15  79.650  94.2  118.35

# %%
df_completo['Churn'] = df_completo['Churn'].replace('', np.nan)
pd.crosstab(df_completo['InternetService'], df_completo['Churn'], normalize='index') * 100
# Out:
# /tmp/ipython-input-2967714965.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_completo['Churn'] = df_completo['Churn'].replace('', np.nan)
# Churn                   No        Yes
# InternetService
# DSL              81.040892  18.959108
# Fiber optic      58.107235  41.892765
# No               92.595020   7.404980

# %%
pd.crosstab(df_completo['PaymentMethod'], df_completo['Churn'], normalize='index') * 100
# Out:
# Churn                             No        Yes
# PaymentMethod
# Bank transfer (automatic)  83.290155  16.709845
# Credit card (automatic)    84.756899  15.243101
# Electronic check           54.714588  45.285412
# Mailed check               80.893300  19.106700

# %%
pd.crosstab(df_completo['Contract'], df_completo['Churn'], normalize='index') * 100
# Out:
# Churn                  No        Yes
# Contract
# Month-to-month  57.290323  42.709677
# One year        88.730482  11.269518
# Two year        97.168142   2.831858

# %%
df_completo.groupby('Churn')['Charges.Monthly'].mean()
# Out:
# Churn
# No     61.265124
# Yes    74.441332
# Name: Charges.Monthly, dtype: float64

# %%
import numpy as np
# Trocar string vazia por NaN
df_completo['Churn'] = df_completo['Churn'].replace('', np.nan)

# Remover registros sem churn definido
df_completo = df_completo.dropna(subset=['Churn'])

# Recriar o crosstab por quartis
df_completo['QuartilMensalidade'] = pd.qcut(
    df_completo['Charges.Monthly'],
    q=4,
    labels=['Q1 (mais baixo)', 'Q2', 'Q3', 'Q4 (mais alto)']
)

tabela = pd.crosstab(
    df_completo['QuartilMensalidade'],
    df_completo['Churn'],
    normalize='index'
) * 100

print(tabela)
# Out:
# Churn                      No        Yes
# QuartilMensalidade
# Q1 (mais baixo)     88.762770  11.237230
# Q2                  75.424689  24.575311
# Q3                  62.492886  37.507114
# Q4 (mais alto)      67.121729  32.878271
# /tmp/ipython-input-2824879419.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_completo['Churn'] = df_completo['Churn'].replace('', np.nan)

# %%
df_completo['Churn'] = df_completo['Churn'].replace('', np.nan)
df_completo.groupby('Churn')['tenure'].describe()
# Out:
#         count       mean        std  min   25%   50%   75%   max
# Churn
# No     5174.0  37.569965  24.113777  0.0  15.0  38.0  61.0  72.0
# Yes    1869.0  17.979133  19.531123  1.0   2.0  10.0  29.0  72.0

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# Configuração do estilo
plt.style.use('default')
sns.set_palette("Set2")

# Função auxiliar para calcular taxa de churn (%)
def churn_rate(df, col):
    return (
        df.groupby(col)["Churn"]
        .value_counts(normalize=True)
        .mul(100)
        .rename("ChurnRate")
        .reset_index()
        .query("Churn == 'Yes'")
    )

# Função auxiliar para calcular taxa de churn completa (todas as categorias)
def churn_rate_complete(df, col):
    churn_data = df.groupby(col)["Churn"].apply(lambda x: (x == 'Yes').mean() * 100).reset_index()
    churn_data.columns = [col, 'ChurnRate']
    return churn_data

# Função para adicionar valores nos gráficos de barra
def add_value_labels(ax, bars, values, format_str='{:.1f}%'):
    """Adiciona rótulos de valores nas barras"""
    for bar, value in zip(bars, values):
        if ax.get_xlabel():  # Barras verticais
            height = bar.get_height()
            ax.text(bar.get_x() + bar.get_width()/2., height + height*0.01,
                   format_str.format(value), ha='center', va='bottom',
                   fontweight='bold', fontsize=10)
        else:  # Barras horizontais
            width = bar.get_width()
            ax.text(width + width*0.01, bar.get_y() + bar.get_height()/2.,
                   format_str.format(value), ha='left', va='center',
                   fontweight='bold', fontsize=10)

# 1. Boxplot de mensalidade x churn
plt.figure(figsize=(8,6))
box_plot = sns.boxplot(data=df_completo, x="Churn", y="Charges.Monthly",
                      palette=['lightblue', 'lightcoral'])
plt.title("Distribuição da Mensalidade por Churn", fontsize=14, fontweight='bold', pad=20)
plt.xlabel("Churn", fontsize=12)
plt.ylabel("Mensalidade (R$)", fontsize=12)

# Adicionar estatísticas no boxplot
medians = df_completo.groupby('Churn')['Charges.Monthly'].median()
for i, (category, median) in enumerate(medians.items()):
    plt.text(i, median, f'Mediana: R${median:.0f}',
             horizontalalignment='center', verticalalignment='bottom',
             bbox=dict(boxstyle='round,pad=0.3', facecolor='white', alpha=0.8),
             fontweight='bold', fontsize=10)

plt.grid(axis='y', alpha=0.3)
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipython-input-3226616320.py:43: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   box_plot = sns.boxplot(data=df_completo, x="Churn", y="Charges.Monthly",

# %%
# 2. Churn por tipo de internet
plt.figure(figsize=(8,6))
internet_data = churn_rate(df_completo, "InternetService")
bars = plt.bar(internet_data["InternetService"], internet_data["ChurnRate"],
               color=['#FF9999', '#66B2FF', '#99FF99'], alpha=0.8, edgecolor='black', linewidth=1)

# Adicionar valores nas barras
add_value_labels(plt.gca(), bars, internet_data["ChurnRate"])

# Adicionar linha da média
avg_churn = df_completo['Churn'].value_counts(normalize=True)['Yes'] * 100
plt.axhline(y=avg_churn, color='red', linestyle='--', alpha=0.7, linewidth=2)
plt.text(0.5, avg_churn + 2, f'Média Geral: {avg_churn:.1f}%',
         fontweight='bold', color='red', ha='center')

plt.title("Taxa de Churn por Tipo de Internet", fontsize=14, fontweight='bold', pad=20)
plt.xlabel("Tipo de Serviço de Internet", fontsize=12)
plt.ylabel("Taxa de Churn (%)", fontsize=12)
plt.ylim(0, max(internet_data["ChurnRate"]) * 1.15)
plt.grid(axis='y', alpha=0.3)
plt.tight_layout()
plt.show()

# %%
# 3. Churn por método de pagamento
plt.figure(figsize=(10,6))
payment_data = churn_rate(df_completo, "PaymentMethod")
bars = plt.barh(payment_data["PaymentMethod"], payment_data["ChurnRate"],
                color=['#FFB366', '#66FFB2', '#B366FF', '#FF66B2'],
                alpha=0.8, edgecolor='black', linewidth=1)

# Adicionar valores nas barras
add_value_labels(plt.gca(), bars, payment_data["ChurnRate"])

# Adicionar linha da média
avg_churn = df_completo['Churn'].value_counts(normalize=True)['Yes'] * 100
plt.axvline(x=avg_churn, color='red', linestyle='--', alpha=0.7, linewidth=2)
plt.text(avg_churn + 2, len(payment_data)/2, f'Média\nGeral:\n{avg_churn:.1f}%',
         fontweight='bold', color='red', va='center', ha='left')

plt.title("Taxa de Churn por Método de Pagamento", fontsize=14, fontweight='bold', pad=20)
plt.xlabel("Taxa de Churn (%)", fontsize=12)
plt.ylabel("Método de Pagamento", fontsize=12)
plt.xlim(0, max(payment_data["ChurnRate"]) * 1.2)
plt.grid(axis='x', alpha=0.3)
plt.tight_layout()
plt.show()

# %%
# Preparar dados absolutos (contagem)
senior_counts = df_completo.groupby(["SeniorCitizen", "Churn"]).size().unstack(fill_value=0)

# Mapear 0/1 para labels
senior_counts.index = senior_counts.index.map({0: "Não Idoso", 1: "Idoso"})

# Criar gráfico empilhado
ax = senior_counts.plot(
    kind="bar",
    stacked=True,
    figsize=(8,6),
    color=["#99CCFF", "#FF9999"],  # azul = não cancelou, vermelho = cancelou
    edgecolor="black",
    linewidth=1
)

# Adicionar valores absolutos dentro das barras
for container in ax.containers:
    ax.bar_label(container, label_type='center', fontsize=10, color='white', fontweight='bold')

# Adicionar porcentagens no topo de cada barra
totals = senior_counts.sum(axis=1)
for i, total in enumerate(totals):
    churn_pct = senior_counts.loc[senior_counts.index[i], "Yes"] / total * 100
    ax.text(i, total + total*0.02,
            f"Churn = {churn_pct:.1f}%",
            ha='center', va='bottom', fontsize=10, fontweight='bold')

# Ajustar título e labels
plt.title("Churn por Faixa Etária (Volume Absoluto e Proporção)", fontsize=14, fontweight='bold', pad=20)
plt.xlabel("Categoria", fontsize=12)
plt.ylabel("Número de Clientes", fontsize=12)
plt.legend(title="Churn", labels=["Não Cancelou", "Cancelou"])
plt.grid(axis='y', alpha=0.3)
plt.tight_layout()
plt.show()

# %%
# 5. Churn por tipo de contrato
plt.figure(figsize=(8,6))
contract_data = churn_rate(df_completo, "Contract")
bars = plt.bar(contract_data["Contract"], contract_data["ChurnRate"],
               color=['#FF6B6B', '#4ECDC4', '#45B7D1'], alpha=0.8,
               edgecolor='black', linewidth=1)

# Adicionar valores no topo das barras
for bar in bars:
    height = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2., height + 1,  # posição um pouco acima da barra
             f'{height:.1f}%', ha='center', va='bottom',
             fontweight='bold', fontsize=10)

# Adicionar linha da média
avg_churn = df_completo['Churn'].value_counts(normalize=True)['Yes'] * 100
plt.axhline(y=avg_churn, color='red', linestyle='--', alpha=0.7, linewidth=2)
plt.text(1, avg_churn + 3, f'Média Geral: {avg_churn:.1f}%',
         fontweight='bold', color='red', ha='center')

# Adicionar contagem de clientes
counts = df_completo['Contract'].value_counts()
for bar, contract in zip(bars, contract_data["Contract"]):
    count = counts[contract]
    plt.text(bar.get_x() + bar.get_width()/2., bar.get_height()/2,
             f'n = {count}', ha='center', va='center',
             fontweight='bold', fontsize=10, color='white',
             bbox=dict(boxstyle='round,pad=0.3', facecolor='black', alpha=0.7))

plt.title("Taxa de Churn por Tipo de Contrato", fontsize=14, fontweight='bold', pad=20)
plt.xlabel("Tipo de Contrato", fontsize=12)
plt.ylabel("Taxa de Churn (%)", fontsize=12)
plt.ylim(0, max(contract_data["ChurnRate"]) * 1.2)
plt.grid(axis='y', alpha=0.3)
plt.xticks(rotation=0)
plt.tight_layout()
plt.show()

# %% [markdown]
# #📄Relatorio Final

# %% [markdown]
# A partir dos dados analisados, é possível chegar aos seguintes insights:
# -Clientes que pagam mensalmente tem uma taxa de churn maior (42,7% destes deixaram de ser clientes).
# -Clientes idosos, apesar de serem uma pequena parcela, também tem uma taxa de churn maior (41,7%).
# -Clientes com uma mensalidade maior tendem a ter uma taxa de churn maior (os quartis 3 e 4 do boxplot de valor de mensalidade somam mais de 60% de taxa de churn).
# -Clientes que optam por pagar com cheque eletrônico apresentam uma taxa de churn mais elevada se comparada aos outros métodos de Pagamento.
# -Clientes que tem fibra ótica como serviço tem uma taxa de churn mais significativa em comparação aos que não tem.
#
# Com todos esses insights, é possível chegar a conclusão que a Empresa conta com um problema de fidelização de clientes, uma vez que as taxas mais elevadas de churn se encontram nos clientes mais novos, que pagam mensalmente, e com maiores mensalidades, indicando uma insatisfação com os serviços prestados, e falta de benefícios para serem clientes a longo prazo, levando a uma elevada taxa de churn.

# %%
o
